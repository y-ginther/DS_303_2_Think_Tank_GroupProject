# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import *
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from sklearn.metrics import roc_curve, auc
import time
import itertools

# %%
games = pd.read_csv("games.csv")
teams = pd.read_csv("teams.csv")
games_details = pd.read_csv("games_details.csv", low_memory = False)
players = pd.read_csv("players.csv")
ranking = pd.read_csv("ranking.csv")
train = pd.read_csv("train.csv")
test1 = pd.read_csv("test1.csv")
test2 = pd.read_csv("test2.csv")

# %%
#games.columns
#games.info()
#clean data and get rid of the missing values
test1 = test1.dropna()
test1.info()
test2 = test1.dropna()
test2.info()
#games.describe()
#ranking.head()
#games['GAME_DATE_EST'] = pd.to_datetime(games['GAME_DATE_EST'])
#games = games.sort_values(by='GAME_DATE_EST', ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 941 entries, 0 to 958
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             941 non-null    int64
#  1   HOME_TEAM_WINS         941 non-null    int64
#  2   HOME_TEAM_PTS_AVG      941 non-null    float64
#  3   AWAY_TEAM_PTS_AVG      941 non-null    float64
#  4   HOME_TEAM_AST_AVG      941 non-null    float64
#  5   AWAY_TEAM_AST_AVG      941 non-null    float64
#  6   HOME_TEAM_REB_AVG      941 non-null    float64
#  7   AWAY_TEAM_REB_AVG      941 non-null    float64
#  8   HOME_TEAM_WIN_PCT      941 non-null    float64
#  9   AWAY_TEAM_WIN_PCT      941 non-null    float64
#  10  HOME_TEAM_FG_PCT_AVG   941 non-null    float64
#  11  AWAY_TEAM_FG_PCT_AVG   941 non-null    float64
#  12  HOME_TEAM_FT_PCT_AVG   941 non-null    float64
#  13  AWAY_TEAM_FT_PCT_AVG   941 non-null    float64
#  14  HOME_TEAM_FG3_PCT_AVG  941 non-null    float64
#  15  AWAY_TEAM_FG3_PCT_AVG  941 non-null    float64
#  16  DIFF_PTS_AVG           941 non-null    float64
#  17  DIFF_AST_AVG           941 non-null    float64
#  18  DIFF_REB_AVG           941 non-null    float64
#  19  DIFF_WIN_PCT           941 non-null    float64
#  20  DIFF_FG_PCT            941 non-null    float64
#  21  DIFF_FT_PCT            941 non-null    float64
#  22  DIFF_FG3_PCT           941 non-null    float64
# dtypes: float64(21), int64(2)
# memory usage: 176.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 941 entries, 0 to 958
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             941 non-null    int64
#  1   HOME_TEAM_WINS         941 non-null    int64
#  2   HOME_TEAM_PTS_AVG      941 non-null    float64
#  3   AWAY_TEAM_PTS_AVG      941 non-null    float64
#  4   HOME_TEAM_AST_AVG      941 non-null    float64
#  5   AWAY_TEAM_AST_AVG      941 non-null    float64
#  6   HOME_TEAM_REB_AVG      941 non-null    float64
#  7   AWAY_TEAM_REB_AVG      941 non-null    float64
#  8   HOME_TEAM_WIN_PCT      941 non-null    float64
#  9   AWAY_TEAM_WIN_PCT      941 non-null    float64
#  10  HOME_TEAM_FG_PCT_AVG   941 non-null    float64
#  11  AWAY_TEAM_FG_PCT_AVG   941 non-null    float64
#  12  HOME_TEAM_FT_PCT_AVG   941 non-null    float64
#  13  AWAY_TEAM_FT_PCT_AVG   941 non-null    float64
#  14  HOME_TEAM_FG3_PCT_AVG  941 non-null    float64
#  15  AWAY_TEAM_FG3_PCT_AVG  941 non-null    float64
#  16  DIFF_PTS_AVG           941 non-null    float64
#  17  DIFF_AST_AVG           941 non-null    float64
#  18  DIFF_REB_AVG           941 non-null    float64
#  19  DIFF_WIN_PCT           941 non-null    float64
#  20  DIFF_FG_PCT            941 non-null    float64
#  21  DIFF_FT_PCT            941 non-null    float64
#  22  DIFF_FG3_PCT           941 non-null    float64
# dtypes: float64(21), int64(2)
# memory usage: 176.4 KB

# %%
train.describe()
# Out:
#         Unnamed: 0  HOME_TEAM_WINS  HOME_TEAM_PTS_AVG  AWAY_TEAM_PTS_AVG  \
# count  2981.000000     2981.000000        2981.000000        2981.000000
# mean   5198.166723        0.604160          98.617691          98.656949
# std    1085.646518        0.489112           4.575190           4.572007
# min    3385.000000        0.000000          86.150000          87.272727
# 25%    4130.000000        0.000000          95.517241          95.490196
# 50%    5172.000000        1.000000          97.824561          97.863636
# 75%    6215.000000        1.000000         100.903226         100.937500
# max    6960.000000        1.000000         111.064935         111.102564
#
#        HOME_TEAM_AST_AVG  AWAY_TEAM_AST_AVG  HOME_TEAM_REB_AVG  \
# count        2981.000000        2981.000000        2981.000000
# mean           21.044420          21.085042          41.589556
# std             1.889828           1.887239           1.721443
# min            15.833333          15.913043          36.952381
# 25%            19.895349          19.902439          40.392157
# 50%            20.855422          20.916667          41.454545
# 75%            22.111111          22.142857          42.675325
# max            27.710526          27.648649          47.500000
#
#        AWAY_TEAM_REB_AVG  HOME_TEAM_WIN_PCT  AWAY_TEAM_WIN_PCT  ...  \
# count        2981.000000        2981.000000        2981.000000  ...
# mean           41.651653           0.503079           0.504534  ...
# std             1.727145           0.158846           0.158859  ...
# min            37.045455           0.086957           0.083333  ...
# 25%            40.463415           0.391304           0.397436  ...
# 50%            41.493976           0.509434           0.506329  ...
# 75%            42.746835           0.626506           0.628571  ...
# max            47.600000           0.888889           0.891892  ...
#
#        AWAY_TEAM_FT_PCT_AVG  HOME_TEAM_FG3_PCT_AVG  AWAY_TEAM_FG3_PCT_AVG  \
# count           2981.000000            2981.000000            2981.000000
# mean               0.754208               0.353185               0.352888
# std                0.029198               0.022598               0.022560
# min                0.669680               0.291167               0.291850
# 25%                0.734333               0.336577               0.336305
# 50%                0.752737               0.351153               0.350433
# 75%                0.771918               0.369486               0.369551
# max                0.838414               0.442304               0.446364
#
#        DIFF_PTS_AVG  DIFF_AST_AVG  DIFF_REB_AVG  DIFF_WIN_PCT  DIFF_FG_PCT  \
# count   2981.000000   2981.000000   2981.000000   2981.000000  2981.000000
# mean      -0.039258     -0.040621     -0.062097     -0.001454    -0.000034
# std        6.382710      2.652849      2.414462      0.225370     0.020393
# min      -19.632056     -9.962934     -8.221839     -0.681818    -0.066469
# 25%       -4.257468     -1.779626     -1.737480     -0.156863    -0.013371
# 50%        0.014604     -0.049407     -0.034305      0.000000    -0.000196
# 75%        4.059091      1.702621      1.594203      0.149254     0.013109
# max       20.923478      9.251894      7.882353      0.644615     0.067696
#
#        DIFF_FT_PCT  DIFF_FG3_PCT
# count  2981.000000   2981.000000
# mean      0.000403      0.000297
# std       0.040166      0.031695
# min      -0.145327     -0.133857
# 25%      -0.027936     -0.020648
# 50%       0.000213      0.000394
# 75%       0.028891      0.021146
# max       0.135080      0.111832
#
# [8 rows x 23 columns]

# %%
# for hometeamwins in win percentage 
np.abs(train.corrwith(train.HOME_TEAM_WINS)).sort_values(ascending = False)
# Out:
# HOME_TEAM_WINS           1.000000
# DIFF_WIN_PCT             0.377975
# HOME_TEAM_WIN_PCT        0.288478
# AWAY_TEAM_WIN_PCT        0.247771
# DIFF_FG_PCT              0.233742
# HOME_TEAM_FG_PCT_AVG     0.191835
# DIFF_FG3_PCT             0.187094
# DIFF_AST_AVG             0.164576
# DIFF_PTS_AVG             0.145673
# HOME_TEAM_AST_AVG        0.144129
# HOME_TEAM_FG3_PCT_AVG    0.138998
# HOME_TEAM_PTS_AVG        0.129687
# AWAY_TEAM_FG_PCT_AVG     0.127021
# AWAY_TEAM_FG3_PCT_AVG    0.123623
# DIFF_REB_AVG             0.116712
# HOME_TEAM_REB_AVG        0.092521
# AWAY_TEAM_AST_AVG        0.087014
# AWAY_TEAM_PTS_AVG        0.073589
# AWAY_TEAM_REB_AVG        0.070941
# HOME_TEAM_FT_PCT_AVG     0.040596
# DIFF_FT_PCT              0.035886
# Unnamed: 0               0.029541
# AWAY_TEAM_FT_PCT_AVG     0.008854
# dtype: float64

# %%
train.corr()
# Out:
#                        Unnamed: 0  HOME_TEAM_WINS  HOME_TEAM_PTS_AVG  \
# Unnamed: 0               1.000000        0.029541           0.030651
# HOME_TEAM_WINS           0.029541        1.000000           0.129687
# HOME_TEAM_PTS_AVG        0.030651        0.129687           1.000000
# AWAY_TEAM_PTS_AVG        0.013016       -0.073589           0.026213
# HOME_TEAM_AST_AVG       -0.063898        0.144129           0.626449
# AWAY_TEAM_AST_AVG       -0.075265       -0.087014           0.035181
# HOME_TEAM_REB_AVG        0.050076        0.092521           0.330090
# AWAY_TEAM_REB_AVG        0.025180       -0.070941          -0.006952
# HOME_TEAM_WIN_PCT        0.000363        0.288478           0.423453
# AWAY_TEAM_WIN_PCT       -0.017744       -0.247771           0.020727
# HOME_TEAM_FG_PCT_AVG     0.014501        0.191835           0.639109
# AWAY_TEAM_FG_PCT_AVG     0.001292       -0.127021           0.055537
# HOME_TEAM_FT_PCT_AVG     0.244524        0.040596           0.256482
# AWAY_TEAM_FT_PCT_AVG     0.250393       -0.008854           0.038134
# HOME_TEAM_FG3_PCT_AVG    0.173477        0.138998           0.299731
# AWAY_TEAM_FG3_PCT_AVG    0.163853       -0.123623           0.032862
# DIFF_PTS_AVG             0.012648        0.145673           0.698034
# DIFF_AST_AVG             0.008024        0.164576           0.421240
# DIFF_REB_AVG             0.017691        0.116712           0.240317
# DIFF_WIN_PCT             0.012763        0.377975           0.283848
# DIFF_FG_PCT              0.009683        0.233742           0.427799
# DIFF_FT_PCT             -0.004634        0.035886           0.158338
# DIFF_FG3_PCT             0.007060        0.187094           0.190312
#
#                        AWAY_TEAM_PTS_AVG  HOME_TEAM_AST_AVG  \
# Unnamed: 0                      0.013016          -0.063898
# HOME_TEAM_WINS                 -0.073589           0.144129
# HOME_TEAM_PTS_AVG               0.026213           0.626449
# AWAY_TEAM_PTS_AVG               1.000000           0.025074
# HOME_TEAM_AST_AVG               0.025074           1.000000
# AWAY_TEAM_AST_AVG               0.627794           0.013390
# HOME_TEAM_REB_AVG              -0.004066           0.193524
# AWAY_TEAM_REB_AVG               0.342970           0.026266
# HOME_TEAM_WIN_PCT               0.016095           0.435670
# AWAY_TEAM_WIN_PCT               0.436493           0.026233
# HOME_TEAM_FG_PCT_AVG            0.053380           0.581250
# AWAY_TEAM_FG_PCT_AVG            0.630956           0.033577
# HOME_TEAM_FT_PCT_AVG            0.041172           0.167410
# AWAY_TEAM_FT_PCT_AVG            0.239314          -0.014623
# HOME_TEAM_FG3_PCT_AVG           0.027159           0.315470
# AWAY_TEAM_FG3_PCT_AVG           0.290005           0.016064
# DIFF_PTS_AVG                   -0.697522           0.431084
# DIFF_AST_AVG                   -0.428751           0.702851
# DIFF_REB_AVG                   -0.248237           0.119188
# DIFF_WIN_PCT                   -0.296331           0.288579
# DIFF_FG_PCT                    -0.423395           0.401483
# DIFF_FT_PCT                    -0.144098           0.132073
# DIFF_FG3_PCT                   -0.187054           0.213490
#
#                        AWAY_TEAM_AST_AVG  HOME_TEAM_REB_AVG  \
# Unnamed: 0                     -0.075265           0.050076
# HOME_TEAM_WINS                 -0.087014           0.092521
# HOME_TEAM_PTS_AVG               0.035181           0.330090
# AWAY_TEAM_PTS_AVG               0.627794          -0.004066
# HOME_TEAM_AST_AVG               0.013390           0.193524
# AWAY_TEAM_AST_AVG               1.000000           0.028007
# HOME_TEAM_REB_AVG               0.028007           1.000000
# AWAY_TEAM_REB_AVG               0.199440           0.019637
# HOME_TEAM_WIN_PCT               0.020380           0.236319
# AWAY_TEAM_WIN_PCT               0.437610          -0.000791
# HOME_TEAM_FG_PCT_AVG            0.039327          -0.063324
# AWAY_TEAM_FG_PCT_AVG            0.571781          -0.007474
# HOME_TEAM_FT_PCT_AVG            0.002113          -0.079397
# AWAY_TEAM_FT_PCT_AVG            0.151398           0.017478
# HOME_TEAM_FG3_PCT_AVG           0.007478          -0.097973
# AWAY_TEAM_FG3_PCT_AVG           0.310244           0.021315
# DIFF_PTS_AVG                   -0.424478           0.239524
# DIFF_AST_AVG                   -0.701862           0.117938
# DIFF_REB_AVG                   -0.122698           0.698925
# DIFF_WIN_PCT                   -0.294099           0.167120
# DIFF_FG_PCT                    -0.390319          -0.040942
# DIFF_FT_PCT                    -0.108523          -0.070302
# DIFF_FG3_PCT                   -0.215491          -0.085025
#
#                        AWAY_TEAM_REB_AVG  HOME_TEAM_WIN_PCT  \
# Unnamed: 0                      0.025180           0.000363
# HOME_TEAM_WINS                 -0.070941           0.288478
# HOME_TEAM_PTS_AVG              -0.006952           0.423453
# AWAY_TEAM_PTS_AVG               0.342970           0.016095
# HOME_TEAM_AST_AVG               0.026266           0.435670
# AWAY_TEAM_AST_AVG               0.199440           0.020380
# HOME_TEAM_REB_AVG               0.019637           0.236319
# AWAY_TEAM_REB_AVG               1.000000           0.012405
# HOME_TEAM_WIN_PCT               0.012405           1.000000
# AWAY_TEAM_WIN_PCT               0.229946          -0.006410
# HOME_TEAM_FG_PCT_AVG           -0.008289           0.596371
# AWAY_TEAM_FG_PCT_AVG           -0.063793           0.016847
# HOME_TEAM_FT_PCT_AVG           -0.007096           0.146570
# AWAY_TEAM_FT_PCT_AVG           -0.076590           0.010857
# HOME_TEAM_FG3_PCT_AVG           0.016037           0.481006
# AWAY_TEAM_FG3_PCT_AVG          -0.096765          -0.002506
# DIFF_PTS_AVG                   -0.250657           0.292006
# DIFF_AST_AVG                   -0.123171           0.295863
# DIFF_REB_AVG                   -0.701333           0.159615
# DIFF_WIN_PCT                   -0.153341           0.709340
# DIFF_FG_PCT                     0.040687           0.424831
# DIFF_FT_PCT                     0.050528           0.098434
# DIFF_FG3_PCT                    0.080309           0.344732
#
#                        AWAY_TEAM_WIN_PCT  ...  AWAY_TEAM_FT_PCT_AVG  \
# Unnamed: 0                     -0.017744  ...              0.250393
# HOME_TEAM_WINS                 -0.247771  ...             -0.008854
# HOME_TEAM_PTS_AVG               0.020727  ...              0.038134
# AWAY_TEAM_PTS_AVG               0.436493  ...              0.239314
# HOME_TEAM_AST_AVG               0.026233  ...             -0.014623
# AWAY_TEAM_AST_AVG               0.437610  ...              0.151398
# HOME_TEAM_REB_AVG              -0.000791  ...              0.017478
# AWAY_TEAM_REB_AVG               0.229946  ...             -0.076590
# HOME_TEAM_WIN_PCT              -0.006410  ...              0.010857
# AWAY_TEAM_WIN_PCT               1.000000  ...              0.149618
# HOME_TEAM_FG_PCT_AVG            0.023099  ...              0.047844
# AWAY_TEAM_FG_PCT_AVG            0.615350  ...              0.142658
# HOME_TEAM_FT_PCT_AVG           -0.006440  ...              0.051838
# AWAY_TEAM_FT_PCT_AVG            0.149618  ...              1.000000
# HOME_TEAM_FG3_PCT_AVG          -0.013607  ...              0.040983
# AWAY_TEAM_FG3_PCT_AVG           0.489248  ...              0.316773
# DIFF_PTS_AVG                   -0.297807  ...             -0.144089
# DIFF_AST_AVG                   -0.292629  ...             -0.118121
# DIFF_REB_AVG                   -0.165052  ...              0.067249
# DIFF_WIN_PCT                   -0.709399  ...             -0.097811
# DIFF_FG_PCT                    -0.434153  ...             -0.069504
# DIFF_FT_PCT                    -0.113434  ...             -0.689327
# DIFF_FG3_PCT                   -0.357935  ...             -0.196250
#
#                        HOME_TEAM_FG3_PCT_AVG  AWAY_TEAM_FG3_PCT_AVG  \
# Unnamed: 0                          0.173477               0.163853
# HOME_TEAM_WINS                      0.138998              -0.123623
# HOME_TEAM_PTS_AVG                   0.299731               0.032862
# AWAY_TEAM_PTS_AVG                   0.027159               0.290005
# HOME_TEAM_AST_AVG                   0.315470               0.016064
# AWAY_TEAM_AST_AVG                   0.007478               0.310244
# HOME_TEAM_REB_AVG                  -0.097973               0.021315
# AWAY_TEAM_REB_AVG                   0.016037              -0.096765
# HOME_TEAM_WIN_PCT                   0.481006              -0.002506
# AWAY_TEAM_WIN_PCT                  -0.013607               0.489248
# HOME_TEAM_FG_PCT_AVG                0.449068               0.019418
# AWAY_TEAM_FG_PCT_AVG                0.023976               0.451148
# HOME_TEAM_FT_PCT_AVG                0.325200               0.036852
# AWAY_TEAM_FT_PCT_AVG                0.040983               0.316773
# HOME_TEAM_FG3_PCT_AVG               1.000000               0.014742
# AWAY_TEAM_FG3_PCT_AVG               0.014742               1.000000
# DIFF_PTS_AVG                        0.195396              -0.184178
# DIFF_AST_AVG                        0.219413              -0.209264
# DIFF_REB_AVG                       -0.081324               0.084416
# DIFF_WIN_PCT                        0.348615              -0.346628
# DIFF_FG_PCT                         0.311622              -0.316482
# DIFF_FT_PCT                         0.206117              -0.203539
# DIFF_FG3_PCT                        0.702489              -0.701262
#
#                        DIFF_PTS_AVG  DIFF_AST_AVG  DIFF_REB_AVG  DIFF_WIN_PCT  \
# Unnamed: 0                 0.012648      0.008024      0.017691      0.012763
# HOME_TEAM_WINS             0.145673      0.164576      0.116712      0.377975
# HOME_TEAM_PTS_AVG          0.698034      0.421240      0.240317      0.283848
# AWAY_TEAM_PTS_AVG         -0.697522     -0.428751     -0.248237     -0.296331
# HOME_TEAM_AST_AVG          0.431084      0.702851      0.119188      0.288579
# AWAY_TEAM_AST_AVG         -0.424478     -0.701862     -0.122698     -0.294099
# HOME_TEAM_REB_AVG          0.239524      0.117938      0.698925      0.167120
# AWAY_TEAM_REB_AVG         -0.250657     -0.123171     -0.701333     -0.153341
# HOME_TEAM_WIN_PCT          0.292006      0.295863      0.159615      0.709340
# AWAY_TEAM_WIN_PCT         -0.297807     -0.292629     -0.165052     -0.709399
# HOME_TEAM_FG_PCT_AVG       0.419883      0.386092     -0.039219      0.404053
# AWAY_TEAM_FG_PCT_AVG      -0.412151     -0.382846      0.040305     -0.421874
# HOME_TEAM_FT_PCT_AVG       0.154357      0.117756     -0.051532      0.107845
# AWAY_TEAM_FT_PCT_AVG      -0.144089     -0.118121      0.067249     -0.097811
# HOME_TEAM_FG3_PCT_AVG      0.195396      0.219413     -0.081324      0.348615
# AWAY_TEAM_FG3_PCT_AVG     -0.184178     -0.209264      0.084416     -0.346628
# DIFF_PTS_AVG               1.000000      0.609068      0.350077      0.415731
# DIFF_AST_AVG               0.609068      1.000000      0.172194      0.414799
# DIFF_REB_AVG               0.350077      0.172194      1.000000      0.228842
# DIFF_WIN_PCT               0.415731      0.414799      0.228842      1.000000
# DIFF_FG_PCT                0.609933      0.563680     -0.058295      0.605456
# DIFF_FT_PCT                0.216717      0.171289     -0.086268      0.149336
# DIFF_FG3_PCT               0.270406      0.305386     -0.118068      0.495276
#
#                        DIFF_FG_PCT  DIFF_FT_PCT  DIFF_FG3_PCT
# Unnamed: 0                0.009683    -0.004634      0.007060
# HOME_TEAM_WINS            0.233742     0.035886      0.187094
# HOME_TEAM_PTS_AVG         0.427799     0.158338      0.190312
# AWAY_TEAM_PTS_AVG        -0.423395    -0.144098     -0.187054
# HOME_TEAM_AST_AVG         0.401483     0.132073      0.213490
# AWAY_TEAM_AST_AVG        -0.390319    -0.108523     -0.215491
# HOME_TEAM_REB_AVG        -0.040942    -0.070302     -0.085025
# AWAY_TEAM_REB_AVG         0.040687     0.050528      0.080309
# HOME_TEAM_WIN_PCT         0.424831     0.098434      0.344732
# AWAY_TEAM_WIN_PCT        -0.434153    -0.113434     -0.357935
# HOME_TEAM_FG_PCT_AVG      0.682076     0.076032      0.306356
# AWAY_TEAM_FG_PCT_AVG     -0.682064    -0.074366     -0.304020
# HOME_TEAM_FT_PCT_AVG      0.082333     0.687742      0.205631
# AWAY_TEAM_FT_PCT_AVG     -0.069504    -0.689327     -0.196250
# HOME_TEAM_FG3_PCT_AVG     0.311622     0.206117      0.702489
# AWAY_TEAM_FG3_PCT_AVG    -0.316482    -0.203539     -0.701262
# DIFF_PTS_AVG              0.609933     0.216717      0.270406
# DIFF_AST_AVG              0.563680     0.171289      0.305386
# DIFF_REB_AVG             -0.058295    -0.086268     -0.118068
# DIFF_WIN_PCT              0.605456     0.149336      0.495276
# DIFF_FG_PCT               1.000000     0.110251      0.447444
# DIFF_FT_PCT               0.110251     1.000000      0.291831
# DIFF_FG3_PCT              0.447444     0.291831      1.000000
#
# [23 rows x 23 columns]

# %%
#home average stats & away average stats), or (difference in average stats)
sns.countplot(data=train, x="HOME_TEAM_PTS_AVG", hue="HOME_TEAM_WINS")
plt.ylim(0, 5)
# Out:
# (0.0, 5.0)

# %%
model = smf.logit("HOME_TEAM_WINS ~ DIFF_WIN_PCT + DIFF_FG_PCT + DIFF_FG3_PCT + DIFF_PTS_AVG + DIFF_AST_AVG + DIFF_REB_AVG + DIFF_FT_PCT", data=train).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.592801
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         HOME_TEAM_WINS   No. Observations:                 2981
# Model:                          Logit   Df Residuals:                     2973
# Method:                           MLE   Df Model:                            7
# Date:                Wed, 01 Mar 2023   Pseudo R-squ.:                  0.1169
# Time:                        14:29:57   Log-Likelihood:                -1767.1
# converged:                       True   LL-Null:                       -2001.1
# Covariance Type:            nonrobust   LLR p-value:                 6.202e-97
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.5064      0.041     12.273      0.000       0.426       0.587
# DIFF_WIN_PCT     3.6697      0.279     13.165      0.000       3.123       4.216
# DIFF_FG_PCT      5.6638      3.413      1.660      0.097      -1.025      12.353
# DIFF_FG3_PCT     1.0700      1.597      0.670      0.503      -2.061       4.201
# DIFF_PTS_AVG    -0.0225      0.010     -2.235      0.025      -0.042      -0.003
# DIFF_AST_AVG     0.0147      0.020      0.721      0.471      -0.025       0.054
# DIFF_REB_AVG     0.0576      0.022      2.656      0.008       0.015       0.100
# DIFF_FT_PCT     -0.5838      1.095     -0.533      0.594      -2.730       1.563
# ================================================================================
# """

# %%
#Function to compute confusion matrix and prediction accuracy on test/train data
def confusion_matrix_data(data,actual_values,model,cutoff=0.5):
#Predict the values using the Logit model
    pred_values = model.predict(train)
# Specify the bins
    bins=np.array([0,cutoff,1])
#Confusion matrix
    cm = np.histogram2d(actual_values, pred_values, bins=bins)[0]
    cm_df = pd.DataFrame(cm)
    cm_df.columns = ['Predicted 0','Predicted 1']
    cm_df = cm_df.rename(index={0: 'Actual 0',1:'Actual 1'})
# Calculate the accuracy
    accuracy = (cm[0,0]+cm[1,1])/cm.sum()
    fnr = (cm[1,0])/(cm[1,0]+cm[1,1])
    precision = (cm[1,1])/(cm[0,1]+cm[1,1])
    fpr = (cm[0,1])/(cm[0,0]+cm[0,1])
    tpr = (cm[1,1])/(cm[1,0]+cm[1,1])
    fpr_roc, tpr_roc, auc_thresholds = roc_curve(actual_values, pred_values)
    auc_value = (auc(fpr_roc, tpr_roc))# AUC of ROC
    sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
    plt.ylabel("Actual Values")
    plt.xlabel("Predicted Values")
    print("Classification accuracy = {:.1%}".format(accuracy))
    print("Precision = {:.1%}".format(precision))
    print("TPR or Recall = {:.1%}".format(tpr))
    print("FNR = {:.1%}".format(fnr))
    print("FPR = {:.1%}".format(fpr))
    print("ROC-AUC = {:.1%}".format(auc_value))

# %%
confusion_matrix_data(train,train.HOME_TEAM_WINS,model,cutoff=0.5)
# Out:
# Classification accuracy = 68.4%
# Precision = 70.4%
# TPR or Recall = 82.2%
# FNR = 17.8%
# FPR = 52.7%
# ROC-AUC = 72.7%

# %%
model2 = smf.logit("HOME_TEAM_WINS ~ DIFF_WIN_PCT + DIFF_FG_PCT + DIFF_FG3_PCT + DIFF_AST_AVG", data=train).fit()
model2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.594467
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         HOME_TEAM_WINS   No. Observations:                 2981
# Model:                          Logit   Df Residuals:                     2976
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 01 Mar 2023   Pseudo R-squ.:                  0.1144
# Time:                        14:55:39   Log-Likelihood:                -1772.1
# converged:                       True   LL-Null:                       -2001.1
# Covariance Type:            nonrobust   LLR p-value:                 8.056e-98
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.5021      0.041     12.203      0.000       0.421       0.583
# DIFF_WIN_PCT     3.9317      0.260     15.135      0.000       3.423       4.441
# DIFF_FG_PCT      0.4577      2.802      0.163      0.870      -5.034       5.949
# DIFF_FG3_PCT    -0.1284      1.504     -0.085      0.932      -3.077       2.820
# DIFF_AST_AVG     0.0067      0.019      0.360      0.719      -0.030       0.043
# ================================================================================
# """

# %%
confusion_matrix_data(train,train.HOME_TEAM_WINS,model2,cutoff=0.5)
# Out:
# Classification accuracy = 68.7%
# Precision = 70.5%
# TPR or Recall = 82.8%
# FNR = 17.2%
# FPR = 52.9%
# ROC-AUC = 72.4%

# %%
from sklearn.metrics import precision_recall_curve
y=train.HOME_TEAM_WINS
ypred = model.predict(train)
p, r, thresholds = precision_recall_curve(y, ypred)
def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    plt.figure(figsize=(8, 8))
    plt.title("Precision and Recall Scores as a function of the decision threshold")
    plt.plot(thresholds, precisions[:-1], "b--", label="Precision")
    plt.plot(thresholds, recalls[:-1], "g-", label="Recall")
    plt.ylabel("Score")
    plt.xlabel("Decision Threshold")
    plt.legend(loc='best')
    plt.legend()
plot_precision_recall_vs_threshold(p, r, thresholds)

# %%
from sklearn.metrics import roc_curve, auc
y=train.HOME_TEAM_WINS
ypred = model.predict(train)
fpr, tpr, auc_thresholds = roc_curve(y, ypred)
print(auc(fpr, tpr))# AUC of ROC
def plot_roc_curve(fpr, tpr, label=None):
    plt.figure(figsize=(8,8))
    plt.title('ROC Curve')
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([-0.005, 1, 0, 1.005])
    plt.xticks(np.arange(0,1, 0.05), rotation=90)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate (Recall)")

fpr, tpr, auc_thresholds = roc_curve(y, ypred)
plot_roc_curve(fpr, tpr)
print(auc)
# Out:
# 0.7267163252053943
# <function auc at 0x7f9acdc4af70>

# %%
from sklearn.metrics import roc_curve, auc
y=train.HOME_TEAM_WINS
ypred = model2.predict(train)
fpr, tpr, auc_thresholds = roc_curve(y, ypred)
print(auc(fpr, tpr))# AUC of ROC
def plot_roc_curve(fpr, tpr, label=None):
    plt.figure(figsize=(8,8))
    plt.title('ROC Curve')
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([-0.005, 1, 0, 1.005])
    plt.xticks(np.arange(0,1, 0.05), rotation=90)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate (Recall)")

fpr, tpr, auc_thresholds = roc_curve(y, ypred)
plot_roc_curve(fpr, tpr)
print(auc)
# Out:
# 0.7259498018991333
# <function auc at 0x7f9acdc4af70>

# %%
y = train.HOME_TEAM_WINS
x = train.drop("HOME_TEAM_WINS", axis = 1)

y_test = test1.HOME_TEAM_WINS
x_test = test1.drop("HOME_TEAM_WINS", axis=1)

# %%
#Function to develop a model based on all predictors in predictor_subset
def processSubset(predictor_subset):
    # Fit model on feature_set and calculate R-squared
    model = sm.logit('HOME_TEAM_WINS~' + '+'.join(predictor_subset),data = train).fit()
    y = train.HOME_TEAM_WINS
    ypred = model.predict(train)
    fpr, tpr, auc_thresholds = roc_curve(y, ypred)
    auc_roc = auc(fpr,tpr)
    return {"model":model, "auc_roc":auc_roc}

# %%
#Function to find the best predictor out of p-k predictors and add it to the model containing the k predictors
def forward(predictors):

    # Pull out predictors we still need to process
    remaining_predictors = [p for p in X.columns if p not in predictors]
    
    tic = time.time()
    
    results = []
    
    for p in remaining_predictors:
        results.append(processSubset(predictors+[p]))
    
    # Wrap everything up in a nice dataframe
    models = pd.DataFrame(results)
    
    # Choose the model with the highest RSS
    best_model = models.loc[models['auc_roc'].argmax()]
    
    toc = time.time()
    print("Processed ", models.shape[0], "models on", len(predictors)+1, "predictors in", (toc-tic), "seconds.")
    
    # Return the best model, along with some other useful information about the model
    return best_model

# %%
def forward_selection():
    models_best = pd.DataFrame(columns=["auc_roc", "model"])

    tic = time.time()
    predictors = []

    for i in range(1,len(X.columns)+1):    
        models_best.loc[i] = forward(predictors)
        predictors = list(models_best.loc[i]["model"].params.index[1:])

    toc = time.time()
    print("Total elapsed time:", (toc-tic), "seconds.")
    return models_best

# %%
models_best = forward_selection()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.671289
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.662699
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.668593
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660647
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.667509
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.666973
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.668776
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.628480
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.639611
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.652314
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663206
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670464
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.671250
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.661490
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663629
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.660561
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.657551
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664434
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.594509
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643176
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670645
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.653444
#          Iterations 5
# Processed  22 models on 1 predictors in 0.14948034286499023 seconds.
# Optimization terminated successfully.
#          Current function value: 0.594509
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594252
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593689
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593859
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594222
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594063
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594394
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594152
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594152
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593456
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593787
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594509
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594024
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594463
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594463
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594417
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594472
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593974
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594490
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594266
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594509
#          Iterations 5
# Processed  21 models on 2 predictors in 0.2001500129699707 seconds.
# Optimization terminated successfully.
#          Current function value: 0.593456
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593439
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593347
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593327
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592771
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593296
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593444
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593444
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593132
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593443
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593083
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593428
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593455
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593046
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593452
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592655
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593132
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593179
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593437
#          Iterations 6
# Processed  20 models on 3 predictors in 0.16361308097839355 seconds.
# Optimization terminated successfully.
#          Current function value: 0.592655
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592431
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591893
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592623
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592515
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592571
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592571
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592655
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592655
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592502
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592652
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592405
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592651
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592622
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591628
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592625
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592502
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592490
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592646
#          Iterations 6
# Processed  19 models on 4 predictors in 0.16013789176940918 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591628
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591608
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591608
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591490
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591617
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591538
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591538
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591586
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591586
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591598
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591623
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591529
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591623
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591474
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591506
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591598
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591595
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591566
#          Iterations 6
# Processed  18 models on 5 predictors in 0.17367219924926758 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591490
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591490
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591490
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591469
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591444
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591444
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591413
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591413
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591441
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591489
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591389
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591477
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591318
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591469
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591441
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591447
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591436
#          Iterations 6
# Processed  17 models on 6 predictors in 0.23261690139770508 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591318
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591314
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591314
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591310
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591279
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591279
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591291
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591291
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591300
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591311
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591126
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591314
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591310
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591300
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591253
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591314
#          Iterations 6
# Processed  16 models on 7 predictors in 0.19514822959899902 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591126
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591126
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591126
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591118
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591082
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591082
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591106
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591106
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591118
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591123
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591120
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591118
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591118
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591123
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591120
#          Iterations 6
# Processed  15 models on 8 predictors in 0.18651914596557617 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591106
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591105
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591105
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591102
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591035
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591035
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591106
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591104
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591103
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591104
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591102
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591104
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591103
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591104
#          Iterations 6
# Processed  14 models on 9 predictors in 0.18796324729919434 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591104
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591101
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591101
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591101
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591035
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591035
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591104
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.591100
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591102
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591101
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591104
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.591100
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591102
#          Iterations 6
# Processed  13 models on 10 predictors in 0.1866922378540039 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591101
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591095
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591095
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591022
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591022
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591101
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591099
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591101
#          Iterations 24
# Optimization terminated successfully.
#          Current function value: 0.591101
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591099
#          Iterations 6
# Processed  12 models on 11 predictors in 0.18785905838012695 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.591097
#          Iterations: 35
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Processed  11 models on 12 predictors in 0.18391776084899902 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# /Users/priyathakore/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/priyathakore/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.591097
#          Iterations: 35
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Processed  11 models on 12 predictors in 0.19319605827331543 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.591097
#          Iterations: 35
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Processed  11 models on 12 predictors in 0.18368887901306152 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# /Users/priyathakore/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/priyathakore/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.591097
#          Iterations: 35
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Processed  11 models on 12 predictors in 0.1890580654144287 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.591097
#          Iterations: 35
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# /Users/priyathakore/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Processed  11 models on 12 predictors in 0.17943191528320312 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.591097
#          Iterations: 35
# /Users/priyathakore/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Processed  11 models on 12 predictors in 0.24844694137573242 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.591097
#          Iterations: 35
# /Users/priyathakore/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/priyathakore/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Processed  11 models on 12 predictors in 0.2021338939666748 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.591097
#          Iterations: 35
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Processed  11 models on 12 predictors in 0.20545220375061035 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.591097
#          Iterations: 35
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# /Users/priyathakore/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/priyathakore/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Processed  11 models on 12 predictors in 0.18871712684631348 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.591097
#          Iterations: 35
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Processed  11 models on 12 predictors in 0.1967010498046875 seconds.
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.591097
#          Iterations: 35
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591093
#          Iterations 6
# Processed  11 models on 12 predictors in 0.18977785110473633 seconds.
# Total elapsed time: 4.215497016906738 seconds.
# /Users/priyathakore/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
def best_sub_plots():
    plt.figure(figsize=(20,10))
    plt.rcParams.update({'font.size': 18, 'lines.markersize': 10})

    # Set up a 2x2 grid so we can look at 4 plots at once
    plt.subplot(2, 2, 1)

    # We will now plot a red dot to indicate the model with the largest adjusted R^2 statistic.
    # The argmax() function can be used to identify the location of the maximum point of a vector
    plt.plot(models_best["auc_roc"])
    plt.xlabel('# Predictors')
    plt.ylabel('auc_roc')

    # We will now plot a red dot to indicate the model with the largest adjusted R^2 statistic.
    # The argmax() function can be used to identify the location of the maximum point of a vector


    # We'll do the same for AIC and BIC, this time looking for the models with the SMALLEST statistic
    aic = models_best.apply(lambda row: row[1].aic, axis=1)

    plt.subplot(2, 2, 3)
    plt.plot(aic)
    plt.plot(1+aic.argmin(), aic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('AIC')

    bic = models_best.apply(lambda row: row[1].bic, axis=1)

    plt.subplot(2, 2, 4)
    plt.plot(bic)
    plt.plot(1+bic.argmin(), bic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('BIC')
best_sub_plots()

# %%
best_subset_model = models_best.loc[4,'model']
models_best.loc[4,'model'].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         HOME_TEAM_WINS   No. Observations:                 2981
# Model:                          Logit   Df Residuals:                     2976
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 01 Mar 2023   Pseudo R-squ.:                  0.1187
# Time:                        15:38:52   Log-Likelihood:                -1763.6
# converged:                       True   LL-Null:                       -2001.1
# Covariance Type:            nonrobust   LLR p-value:                1.759e-101
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -4.6321      1.471     -3.149      0.002      -7.515      -1.749
# DIFF_WIN_PCT             3.7857      0.231     16.368      0.000       3.332       4.239
# HOME_TEAM_FG_PCT_AVG    11.3300      3.245      3.492      0.000       4.970      17.690
# DIFF_REB_AVG             0.0544      0.019      2.904      0.004       0.018       0.091
# DIFF_PTS_AVG            -0.0193      0.008     -2.471      0.013      -0.035      -0.004
# ========================================================================================
# """

# %%
confusion_matrix_data(train,train.HOME_TEAM_WINS,best_subset_model,cutoff=0.5)
# Out:
# Classification accuracy = 68.6%
# Precision = 70.7%
# TPR or Recall = 82.2%
# FNR = 17.8%
# FPR = 52.0%
# ROC-AUC = 72.8%

# %%
X_backup = x.copy()

# %%
#Including 2-factor interactions of predictors in train and 'X'. Note that we need train to develop the model, and X to 
#find 'k' variable subsets from amongst all the predictors under consideration
for combo in itertools.combinations(X_backup.columns, 2):    
    train['_'.join(combo)] = train[combo[0]]*train[combo[1]]
    test1['_'.join(combo)] = test1[combo[0]]*test1[combo[1]]
    X.loc[:,'_'.join(combo)] = train.loc[:,'_'.join(combo)]

# %%
train.head()
# Out:
#    Unnamed: 0  HOME_TEAM_WINS  HOME_TEAM_PTS_AVG  AWAY_TEAM_PTS_AVG  \
# 0        5881               0          90.437500          91.250000
# 1        5882               1          99.933333          97.444444
# 2        5883               1         100.647059          92.526316
# 3        5884               1          98.411765          99.352941
# 4        5885               1          91.888889          97.421053
#
#    HOME_TEAM_AST_AVG  AWAY_TEAM_AST_AVG  HOME_TEAM_REB_AVG  AWAY_TEAM_REB_AVG  \
# 0          19.312500          20.875000          40.187500          39.375000
# 1          21.666667          18.277778          46.266667          44.000000
# 2          21.470588          20.736842          43.529412          42.473684
# 3          21.529412          19.764706          47.352941          39.470588
# 4          16.000000          19.000000          41.722222          39.894737
#
#    HOME_TEAM_WIN_PCT  AWAY_TEAM_WIN_PCT  ...  DIFF_REB_AVG_DIFF_WIN_PCT  \
# 0           0.250000           0.437500  ...                  -0.152344
# 1           0.800000           0.500000  ...                   0.680000
# 2           0.705882           0.315789  ...                   0.411832
# 3           0.470588           0.647059  ...                  -1.391003
# 4           0.277778           0.263158  ...                   0.026718
#
#    DIFF_REB_AVG_DIFF_FG_PCT  DIFF_REB_AVG_DIFF_FT_PCT  \
# 0                 -0.027980                 -0.037426
# 1                  0.066161                 -0.048633
# 2                  0.030999                  0.000742
# 3                 -0.162747                  0.294893
# 4                 -0.063305                 -0.117953
#
#    DIFF_REB_AVG_DIFF_FG3_PCT  DIFF_WIN_PCT_DIFF_FG_PCT  \
# 0                  -0.039762                  0.006457
# 1                   0.008890                  0.008757
# 2                  -0.027419                  0.011454
# 3                  -0.720076                  0.003644
# 4                  -0.002437                 -0.000506
#
#    DIFF_WIN_PCT_DIFF_FT_PCT  DIFF_WIN_PCT_DIFF_FG3_PCT  \
# 0                  0.008637                   0.009176
# 1                 -0.006437                   0.001177
# 2                  0.000274                  -0.010132
# 3                 -0.006602                   0.016121
# 4                 -0.000944                  -0.000019
#
#    DIFF_FG_PCT_DIFF_FT_PCT  DIFF_FG_PCT_DIFF_FG3_PCT  DIFF_FT_PCT_DIFF_FG3_PCT
# 0                 0.001586                  0.001685                  0.002254
# 1                -0.000626                  0.000114                 -0.000084
# 2                 0.000021                 -0.000763                 -0.000018
# 3                -0.000772                  0.001886                 -0.003418
# 4                 0.002236                  0.000046                  0.000086
#
# [5 rows x 254 columns]

# %%
#Function to select the best model amongst all models with 'k' predictors
def getBest_model(k):
    tic = time.time()
    results = []
    for combo in itertools.combinations(X.columns, k):
        results.append(processSubset((list(combo))))

    # Wrap everything up in a dataframe
    models = pd.DataFrame(results)

    # Choose the model with the highest RSS
    best_model = models.loc[models['roc_auc'].argmax()]
    
    toc = time.time()
    print("Processed", models.shape[0], "models on", k, "predictors in", (toc-tic), "seconds.")
    return best_model

# %%
models_best = pd.DataFrame(columns=["roc_auc", "model"])

tic = time.time()
for i in range(1,1+x.shape[1]):
    models_best.loc[i] = getBest_model(i)

toc = time.time()
print("Total elapsed time:", (toc-tic), "seconds.")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.671289
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.662699
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.668593
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660647
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.667509
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.666973
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.668776
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.628480
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.639611
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.652314
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663206
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670464
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.671250
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.661490
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663629
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.660561
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.657551
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664434
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.594509
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643176
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670645
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.653444
#          Iterations 5
# Traceback (most recent call last):
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [146] in <cell line: 4>
#     models_best.loc[i] = getBest_model(i)
#
#   Input In [145] in getBest_model
#     results.append(processSubset((list(combo))))
#
#   Input In [95] in processSubset
#     model = sm.logit('HOME_TEAM_WINS~' + '+'.join(predictor_subset),data = train).fit()
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:200 in from_formula
#     tmp = handle_formula_data(data, None, formula, depth=eval_env,
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/formula/formulatools.py:63 in handle_formula_data
#     result = dmatrices(formula, Y, depth, return_type='dataframe',
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/highlevel.py:309 in dmatrices
#     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/highlevel.py:164 in _do_highlevel_design
#     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/highlevel.py:66 in _try_incr_builders
#     return design_matrix_builders([formula_like.lhs_termlist,
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/build.py:689 in design_matrix_builders
#     factor_states = _factors_memorize(all_factors, data_iter_maker, eval_env)
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/build.py:354 in _factors_memorize
#     which_pass = factor.memorize_passes_needed(state, eval_env)
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/eval.py:474 in memorize_passes_needed
#     subset_names = [name for name in ast_names(self.code)
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/eval.py:474 in <listcomp>
#     subset_names = [name for name in ast_names(self.code)
#
#   File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/eval.py:105 in ast_names
#     for node in ast.walk(ast.parse(code)):
#
#   File ~/opt/anaconda3/lib/python3.9/ast.py:50 in parse
#     return compile(source, filename, mode, flags,
#
#   File <unknown>:1
#     0 _HOME_TEAM_PTS_AVG
#       ^
# SyntaxError: invalid syntax

# %%
model2 = smf.logit("HOME_TEAM_WINS ~ DIFF_WIN_PCT * DIFF_FG_PCT + DIFF_FG3_PCT + DIFF_AST_AVG", data=train).fit()
model2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.594430
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         HOME_TEAM_WINS   No. Observations:                 2981
# Model:                          Logit   Df Residuals:                     2975
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 01 Mar 2023   Pseudo R-squ.:                  0.1145
# Time:                        15:57:05   Log-Likelihood:                -1772.0
# converged:                       True   LL-Null:                       -2001.1
# Covariance Type:            nonrobust   LLR p-value:                 8.222e-97
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.4929      0.045     10.843      0.000       0.404       0.582
# DIFF_WIN_PCT                 3.9392      0.260     15.131      0.000       3.429       4.449
# DIFF_FG_PCT                  0.6018      2.819      0.213      0.831      -4.924       6.127
# DIFF_WIN_PCT:DIFF_FG_PCT     4.5151      9.544      0.473      0.636     -14.190      23.220
# DIFF_FG3_PCT                -0.1286      1.504     -0.086      0.932      -3.077       2.820
# DIFF_AST_AVG                 0.0067      0.019      0.363      0.717      -0.030       0.043
# ============================================================================================
# """

# %%
# Out:
# Optimization terminated successfully.
#          Current function value: 0.594462
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         HOME_TEAM_WINS   No. Observations:                 2981
# Model:                          Logit   Df Residuals:                     2975
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 01 Mar 2023   Pseudo R-squ.:                  0.1144
# Time:                        16:02:37   Log-Likelihood:                -1772.1
# converged:                       True   LL-Null:                       -2001.1
# Covariance Type:            nonrobust   LLR p-value:                 9.034e-97
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     0.5051      0.044     11.407      0.000       0.418       0.592
# DIFF_FG_PCT                   0.4537      2.802      0.162      0.871      -5.038       5.945
# DIFF_FG3_PCT                 -0.1541      1.511     -0.102      0.919      -3.115       2.807
# DIFF_WIN_PCT                  3.9290      0.260     15.102      0.000       3.419       4.439
# DIFF_FG3_PCT:DIFF_WIN_PCT    -1.1691      6.270     -0.186      0.852     -13.458      11.120
# DIFF_AST_AVG                  0.0067      0.019      0.362      0.718      -0.030       0.043
# =============================================================================================
# """

# %%
model3 = smf.logit("HOME_TEAM_WINS ~ DIFF_WIN_PCT * DIFF_FG_PCT * DIFF_FG3_PCT * DIFF_AST_AVG", data=train).fit()
model3.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.592032
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         HOME_TEAM_WINS   No. Observations:                 2981
# Model:                          Logit   Df Residuals:                     2965
# Method:                           MLE   Df Model:                           15
# Date:                Wed, 01 Mar 2023   Pseudo R-squ.:                  0.1181
# Time:                        16:04:46   Log-Likelihood:                -1764.8
# converged:                       True   LL-Null:                       -2001.1
# Covariance Type:            nonrobust   LLR p-value:                 3.617e-91
# ======================================================================================================================
#                                                          coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                              0.5109      0.049     10.509      0.000       0.416       0.606
# DIFF_WIN_PCT                                           4.0660      0.285     14.280      0.000       3.508       4.624
# DIFF_FG_PCT                                            0.7312      3.084      0.237      0.813      -5.314       6.776
# DIFF_WIN_PCT:DIFF_FG_PCT                               5.7118     14.758      0.387      0.699     -23.213      34.637
# DIFF_FG3_PCT                                          -1.5866      1.701     -0.933      0.351      -4.920       1.746
# DIFF_WIN_PCT:DIFF_FG3_PCT                              4.7963      8.806      0.545      0.586     -12.463      22.056
# DIFF_FG_PCT:DIFF_FG3_PCT                            -207.6680    103.928     -1.998      0.046    -411.363      -3.973
# DIFF_WIN_PCT:DIFF_FG_PCT:DIFF_FG3_PCT                320.5095    396.017      0.809      0.418    -455.671    1096.690
# DIFF_AST_AVG                                           0.0221      0.021      1.041      0.298      -0.019       0.064
# DIFF_WIN_PCT:DIFF_AST_AVG                              0.0289      0.119      0.243      0.808      -0.204       0.262
# DIFF_FG_PCT:DIFF_AST_AVG                               0.2456      0.885      0.278      0.781      -1.488       1.979
# DIFF_WIN_PCT:DIFF_FG_PCT:DIFF_AST_AVG                 -8.4640      3.666     -2.309      0.021     -15.649      -1.279
# DIFF_FG3_PCT:DIFF_AST_AVG                             -0.4372      0.744     -0.588      0.557      -1.895       1.021
# DIFF_WIN_PCT:DIFF_FG3_PCT:DIFF_AST_AVG                 1.6572      3.634      0.456      0.648      -5.465       8.780
# DIFF_FG_PCT:DIFF_FG3_PCT:DIFF_AST_AVG                 18.1408     28.204      0.643      0.520     -37.138      73.419
# DIFF_WIN_PCT:DIFF_FG_PCT:DIFF_FG3_PCT:DIFF_AST_AVG    78.7214     82.723      0.952      0.341     -83.413     240.856
# ======================================================================================================================
# """

# %%
confusion_matrix_data(train,train.HOME_TEAM_WINS,model3,cutoff=0.5)
# Out:
# Classification accuracy = 68.3%
# Precision = 70.3%
# TPR or Recall = 82.3%
# FNR = 17.7%
# FPR = 53.0%
# ROC-AUC = 72.6%
